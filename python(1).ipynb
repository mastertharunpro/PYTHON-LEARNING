# %% [markdown]
# ## PYTHON PART(1)

# %% [markdown]
# - INT= 1,2,3
# - FLOAT = 1.2,2.3,3.4
# - COMPLEX = 3+5J,5+4J

# %% [markdown]
# # VARIABLE
# - ACT AS AN STORAGE

# %% [markdown]
# # STRINGS
# - '' = SINGLE COATS
# - "" = DOUBLE COATS
# - """""" = TRIPLE COATS

# %%
word1 = 'hello'
word2 = "hello"
word3 = """hello
my name is tharun"""

# %%
print(word1)
print(word2)
print(word3)
# Out:
# hello
# hello
# hello
# my name is tharun

# %% [markdown]
# # SLICE
# - SEPERATING THE WORD
#
# - NOTE:FOR INDICES USE [] REGTANGULAR BRACKET
#
# - NOTE:LAST WORD WON'T PRINT

# %%
word = "hello this is tharun"

# %%
print(word[6])
# Out:
# t

# %%
print(word[1:13])
# Out:
# ello this is

# %% [markdown]
# # LENGTH

# %%
print(len(word))
# Out:
# 20

# %% [markdown]
# #  STRIP
# - REMOVES UNWANTED SPACES

# %%
word = "   hello   "

# %%
print(word)
# Out:
#    hello

# %%
print(word.strip())
# Out:
# hello

# %% [markdown]
# # UPPERCASE AND LOWER CASE

# %%
print(word.upper())
# Out:
#    HELLO

# %%
print(word.lower())
# Out:
#    hello

# %% [markdown]
# # REPLACING
# - TAKING A LETTER AND REPLACING ANOTHER LETTER

# %%
name = "tharue"

# %%
print(name.replace("e","n"))
# Out:
# tharun

# %% [markdown]
# # SPLIT
# - IT IS USED TO SEPERATE WORDS

# %%
print(name.split("a"))
# Out:
# ['th', 'rue']

# %% [markdown]
# # SPACING
# - GIVING SPACE TO THE WORD

# %%
a1 = "hi"
a2 = "tharun"

# %%
print(a1+a2)
# Out:
# hitharun

# %%
a1 = "hi"
a2 = " tharun"

# %%
print(a1+a2)
# Out:
# hi tharun

# %% [markdown]
# # OPERATORS &  KEYWORDS
#
# # TYPES OF OPERATERS:
#
# - ARITHMETIC
# - COMPARISON
# - ASSIGNMENT
# - LOGICAL
# - BITWISE
# - MEMBERSHIP
# - IDENTITY

# %% [markdown]
# BOOLEAN: USED FOR CONDITION

# %%
print(1>10)
# Out:
# False

# %%
print(1>10)
# Out:
# False

# %%
print(1==10)
# Out:
# False

# %%
print(1<10)
# Out:
# True

# %% [markdown]
# ARITHMETIC OPERATORS [+,-,*,/,//,%,**]

# %%
x = 5
y = 3

# %%
a = x+y
b = x-y
c = x*y
d = x/y
e = x//y
f = x%y
g = x**y

# %%
print(a,b,c,d,e,f,g)
# Out:
# 8 2 15 1.6666666666666667 1 2 125

# %% [markdown]
#  ASSIGNMENT OPERATORS[=]

# %%
a1 = 10 
a2 = 10 + a1
print(a1+a2)
# Out:
# 30

# %% [markdown]
# COMPARISON[==;!=;>;<;>=;<=]

# %%
x = 15
y = 2

x==y
# Out:
# False

# %% [markdown]
# LOGICAL OPERATORS[AND,OR,NOT]
# - and = condition will check the allthings and allow
# - or = in or condition any one is satisfied it will allow
# - not = false

# %%
x = 5
x > 0 and x > 4
print(x > 0 or x > 4)
not x
# Out:
# True
# False

# %% [markdown]
# BITWISE OPERATORS: [&,1,^,,<<,>>]
#
# - IT WILL STORE THE WORDS INTO BINARY NUMBER FORUMLA
# - BINARYS[8421] 64 ETC...

# %% [markdown]
# IDENTITY OPERATORS: [IS,IS NOT]
#
# - IT IS USED TO FIND THE VSRIABLE OF THE TWO GIVEN STRINGS
# -  IT CHECKS ID VALUE ARE SAME (OR) NOT

# %%
a = 23
b = 23

br = a is b 
print(br)
br = a is not b 
print(br)
# Out:
# True
# False

# %% [markdown]
# MEMBERSHIP OPERATORS: [IS, IS NOT]
#
# - USED TO CHECK WEATHER THE GIVEN SENTENCE IS PRESENT IN (STR) STRING (OR) LIST

# %%
print('T' in "Tharun")
print('A' in "Tharun")
# Out:
# True
# False

# %% [markdown]
# # CASTING
#
# - CHANGING OF FLOAT (OR) INTEGER FOR O/P IS KNOWN AS CASTIN

# %%
a = 10 
b = 10.10
print(a,b)
# Out:
# 10 10.1

# %%
a = 10
b = int(10.10)
print(a,b)
# Out:
# 10 10

# %%
a = float(15)
b = int(4.25)
c = str(4)
print(a,b,c)
# Out:
# 15.0 4 4

# %% [markdown]
# # LIST
#
# - HERE [] SQUARE BRACKETS ARE USED ARE USED
# SORTING  OF SOME KIND OF THINGS IN ONE ELEMENT

# %%
fruit = ('apple','orange','grapes')
print(fruit)
# Out:
# ('apple', 'orange', 'grapes')

# %%
print(fruit[0])
# Out:
# apple

# %%
print(fruit[1])
# Out:
# orange

# %%
print(fruit[2])
# Out:
# grapes

# %% [markdown]
# TO CHANGE FRUIT:

# %%
fruit = ['apple','orange','watermelon']

# %%
fruit[1] = "cherry"
print(fruit)
# Out:
# ['apple', 'cherry', 'watermelon']

# %% [markdown]
# APPEND

# %%
fruits = ['apple']
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'orange']

# %%
num = [1,3,4,6,1,3]
num.sort()
print(num)
# Out:
# [1, 1, 3, 3, 4, 6]

# %%
my_data = {"name" : "tharun",
           "age" : "11",
           "city" : "chennai"}

# %%
my_data
# Out:
# {'name': 'tharun', 'age': '11', 'city': 'chennai'}

# %% [markdown]
# my_data["age"]

# %%
wallet = 300

# %%
if wallet > 400:
    print("you can place order")
elif wallet==400:
    print("you can place order,but recharge your wallet")
else:
    print("you have insufficiant money in wallet")
# Out:
# you have insufficiant money in wallet

# %%
age = 20

# %%
if age>18:
    print("eligible to vote")
elif age==18:
    print("apply voter id")

else:
    print("not eligible for voting")
# Out:
# eligible to vote
